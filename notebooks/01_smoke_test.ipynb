# %%
import pandas as pd

# %%
df = pd.read_csv("../data/sample.csv")
print("Shape:", df.shape)
print(df.head())
print(df.describe())
# Out:
# Shape: (5, 3)
#   device_id  temperature  active
# 0       D01         36.5    True
# 1       D02         42.1   False
# 2       D03         30.2    True
# 3       D04         55.0   False
# 4       D05         28.7    True
#        temperature
# count      5.00000
# mean      38.50000
# std       10.65528
# min       28.70000
# 25%       30.20000
# 50%       36.50000
# 75%       42.10000
# max       55.00000
